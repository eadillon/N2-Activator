# %%
import os
os.chdir('/Users/enricadillon/Python/N2predicter/unCORker')
from charcuterie_zax import wine_and_dine
file= '/Users/enricadillon/Python/data/terminal_zax.cor'
training_data,test_data,validation_data=wine_and_dine(file)
# Out:
# The cheese has been cut.
# Now the wine can be unCORked.
# UnCORking LOGPIK.cor - 0.0% complete
# UnCORking HUTQES.cor - 0.2% complete
# UnCORking SOFGUS.cor - 0.3% complete
# UnCORking ZUNYUF.cor - 0.5% complete
# UnCORking RANKAT.cor - 0.6% complete
# UnCORking BUJSOQ.cor - 0.8% complete
# UnCORking QOBRAE.cor - 0.9% complete
# UnCORking QACHIM.cor - 1.1% complete
# UnCORking UGAKIZ.cor - 1.2% complete
# UnCORking RANSEI.cor - 1.4% complete
# UnCORking TUDPUG.cor - 1.5% complete
# UnCORking BARFAF.cor - 1.7% complete
# UnCORking ANAZEV.cor - 1.8% complete
# UnCORking MONVEU.cor - 2.0% complete
# UnCORking QOBQIL.cor - 2.1% complete
# UnCORking MIJTIJ.cor - 2.3% complete
# UnCORking MEZYEX.cor - 2.4% complete
# UnCORking DIJPUL.cor - 2.6% complete
# UnCORking IQACEL.cor - 2.8% complete
# UnCORking DESJUJ.cor - 2.9% complete
# UnCORking CITQEE.cor - 3.1% complete
# UnCORking XURXIT.cor - 3.2% complete
# UnCORking CITZUC.cor - 3.4% complete
# UnCORking SOLXEZ.cor - 3.5% complete
# ...

# %%
# convert 

os.chdir('/Users/enricadillon/Python/N2predicter')
import pandas as pd
from sph2cart import sph2cart
os.chdir('/Users/enricadillon/Python/data/cor_files/search4/')
#convert df in sph back to df in cart
table4[['x', 'y', 'z']] = table4.apply(lambda row: pd.Series(sph2cart(row['r'], row['phi'], row['theta'])), axis=1)
table4_back = table4.drop(['r','phi','theta'],axis=1)
table4_back.to_csv('read2.xyz',index=False,header=False,sep=' ')
table4_back
